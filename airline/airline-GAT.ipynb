# %%
import time
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
plt.style.use('ggplot')
import networkx as nx
# from node2vec import Node2Vec

df0 = pd.read_csv('train.csv',sep=',')
#df1 = pd.read_csv('test.csv',sep=',')

# %%
df = df0.sample(n=5000)

# %%
# Check for missing data
df.isna().sum()
# Out:
# Unnamed: 0                           0
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             8
# satisfaction                         0
# dtype: int64

# %%
df.head()
# Out:
#        Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 62273       62273  112002  Female     Loyal Customer   18  Business travel
# 43485       43485    8698    Male     Loyal Customer   37  Business travel
# 6622         6622  108587    Male     Loyal Customer   53  Business travel
# 81236       81236   25261    Male     Loyal Customer   49  Business travel
# 35211       35211   66534    Male  disloyal Customer   22  Business travel
#
#           Class  Flight Distance  Inflight wifi service  \
# 62273  Eco Plus              770                      3
# 43485       Eco              280                      2
# 6622   Business             2149                      4
# 81236       Eco              425                      5
# 35211       Eco              333                      3
#
#        Departure/Arrival time convenient  ...  Inflight entertainment  \
# 62273                                  5  ...                       3
# 43485                                  4  ...                       2
# 6622                                   3  ...                       4
# 81236                                  1  ...                       5
# 35211                                  2  ...                       3
#
#        On-board service  Leg room service  Baggage handling  Checkin service  \
# 62273                 1                 1                 3                4
# 43485                 5                 5                 1                1
# 6622                  4                 4                 4                4
# 81236                 3                 1                 5                5
# 35211                 1                 3                 3                2
#
#        Inflight service  Cleanliness  Departure Delay in Minutes  \
# 62273                 4            3                          56
# 43485                 4            2                           0
# 6622                  4            3                           0
# 81236                 5            5                           0
# 35211                 4            3                           0
#
#        Arrival Delay in Minutes             satisfaction
# 62273                      47.0  neutral or dissatisfied
# 43485                       0.0                satisfied
# 6622                        0.0                satisfied
# 81236                       0.0                satisfied
# 35211                       0.0  neutral or dissatisfied
#
# [5 rows x 25 columns]

# %%
df.drop(columns=['Unnamed: 0','id'],inplace=True)

# %%
df.head()
# Out:
#        Gender      Customer Type  Age   Type of Travel     Class  \
# 62273  Female     Loyal Customer   18  Business travel  Eco Plus
# 43485    Male     Loyal Customer   37  Business travel       Eco
# 6622     Male     Loyal Customer   53  Business travel  Business
# 81236    Male     Loyal Customer   49  Business travel       Eco
# 35211    Male  disloyal Customer   22  Business travel       Eco
#
#        Flight Distance  Inflight wifi service  \
# 62273              770                      3
# 43485              280                      2
# 6622              2149                      4
# 81236              425                      5
# 35211              333                      3
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# 62273                                  5                       5
# 43485                                  4                       1
# 6622                                   3                       4
# 81236                                  1                       2
# 35211                                  2                       3
#
#        Gate location  ...  Inflight entertainment  On-board service  \
# 62273              5  ...                       3                 1
# 43485              1  ...                       2                 5
# 6622               4  ...                       4                 4
# 81236              1  ...                       5                 3
# 35211              4  ...                       3                 1
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# 62273                 1                 3                4                 4
# 43485                 5                 1                1                 4
# 6622                  4                 4                4                 4
# 81236                 1                 5                5                 5
# 35211                 3                 3                2                 4
#
#        Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 62273            3                          56                      47.0
# 43485            2                           0                       0.0
# 6622             3                           0                       0.0
# 81236            5                           0                       0.0
# 35211            3                           0                       0.0
#
#                   satisfaction
# 62273  neutral or dissatisfied
# 43485                satisfied
# 6622                 satisfied
# 81236                satisfied
# 35211  neutral or dissatisfied
#
# [5 rows x 23 columns]

# %%
df.satisfaction.unique()
# Out:
# array(['neutral or dissatisfied', 'satisfied'], dtype=object)

# %%
df.Gender = df.Gender.apply(lambda x: 0 if x == 'Male' else 1)
df['Customer Type'] = df['Customer Type'].apply(lambda x: 0 if x == 'Loyal Customer' else 1)
df['Type of Travel'] = df['Type of Travel'].apply(lambda x: 0 if x == 'Personal Travel' else 1)
df['Class'] = df['Class'].apply(lambda x: 0 if x == 'Eco' else(1 if x == 'Eco Plus' else 2))
df['satisfaction'] = df['satisfaction'].apply(lambda x: 0 if x == 'neutral or dissatisfied' else 1)

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#       Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0          1              0   18               1      1              770
# 1          0              0   37               1      0              280
# 2          0              0   53               1      2             2149
# 3          0              0   49               1      0              425
# 4          0              1   22               1      0              333
# ...      ...            ...  ...             ...    ...              ...
# 4995       0              0   49               0      0              189
# 4996       1              0   37               1      0              102
# 4997       0              0   55               0      0             1999
# 4998       0              0   56               1      2             3980
# 4999       1              0   27               0      0              321
#
#       Inflight wifi service  Departure/Arrival time convenient  \
# 0                         3                                  5
# 1                         2                                  4
# 2                         4                                  3
# 3                         5                                  1
# 4                         3                                  2
# ...                     ...                                ...
# 4995                      3                                  1
# 4996                      3                                  4
# 4997                      4                                  4
# 4998                      4                                  4
# 4999                      3                                  5
#
#       Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                          5              5  ...                       3
# 1                          1              1  ...                       2
# 2                          4              4  ...                       4
# 3                          2              1  ...                       5
# 4                          3              4  ...                       3
# ...                      ...            ...  ...                     ...
# 4995                       3              4  ...                       1
# 4996                       3              4  ...                       3
# 4997                       4              1  ...                       5
# 4998                       4              4  ...                       4
# 4999                       3              1  ...                       4
#
#       On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                    1                 1                 3                4
# 1                    5                 5                 1                1
# 2                    4                 4                 4                4
# 3                    3                 1                 5                5
# 4                    1                 3                 3                2
# ...                ...               ...               ...              ...
# 4995                 1                 3                 3                4
# 4996                 3                 2                 2                3
# 4997                 5                 4                 5                5
# 4998                 4                 4                 4                5
# 4999                 2                 3                 3                1
#
#       Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                    4            3                          56
# 1                    4            2                           0
# 2                    4            3                           0
# 3                    5            5                           0
# 4                    4            3                           0
# ...                ...          ...                         ...
# 4995                 4            1                           0
# 4996                 2            3                           0
# 4997                 4            5                           4
# 4998                 4            3                           8
# 4999                 2            4                          13
#
#       Arrival Delay in Minutes  satisfaction
# 0                         47.0             0
# 1                          0.0             1
# 2                          0.0             1
# 3                          0.0             1
# 4                          0.0             0
# ...                        ...           ...
# 4995                       0.0             0
# 4996                       6.0             0
# 4997                       0.0             1
# 4998                       9.0             1
# 4999                       8.0             0
#
# [5000 rows x 23 columns]

# %%
df.drop(columns=['Arrival Delay in Minutes'],inplace = True)

# %%
# max number of graph generation features
np.log(len(df))
# Out:
# 8.517193191416238

# %%
df.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       1              0   18               1      1              770
# 1       0              0   37               1      0              280
# 2       0              0   53               1      2             2149
# 3       0              0   49               1      0              425
# 4       0              1   22               1      0              333
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  5
# 1                      2                                  4
# 2                      4                                  3
# 3                      5                                  1
# 4                      3                                  2
#
#    Ease of Online booking  Gate location  ...  Seat comfort  \
# 0                       5              5  ...             2
# 1                       1              1  ...             2
# 2                       4              4  ...             5
# 3                       2              1  ...             5
# 4                       3              4  ...             3
#
#    Inflight entertainment  On-board service  Leg room service  \
# 0                       3                 1                 1
# 1                       2                 5                 5
# 2                       4                 4                 4
# 3                       5                 3                 1
# 4                       3                 1                 3
#
#    Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                 3                4                 4            3
# 1                 1                1                 4            2
# 2                 4                4                 4            3
# 3                 5                5                 5            5
# 4                 3                2                 4            3
#
#    Departure Delay in Minutes  satisfaction
# 0                          56             0
# 1                           0             1
# 2                           0             1
# 3                           0             1
# 4                           0             0
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'satisfaction'],
#       dtype='object')

# %% [markdown]
# Following variables are used for the graph generation:
#
# - Gender
# - Customer Type
# - Age
# - Type of Travel
# - Class

# %%
df.Age.describe()
# Out:
# count    5000.000000
# mean       39.306000
# std        15.024337
# min         7.000000
# 25%        27.000000
# 50%        40.000000
# 75%        51.000000
# max        85.000000
# Name: Age, dtype: float64

# %%
X = df

# %%
X.Age = X.Age.apply(lambda x: 0 if x < 26 else(1 if x < 39 else(2 if x < 50 else 3)))

# %%
X
# Out:
#       Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0          1              0    0               1      1              770
# 1          0              0    1               1      0              280
# 2          0              0    3               1      2             2149
# 3          0              0    2               1      0              425
# 4          0              1    0               1      0              333
# ...      ...            ...  ...             ...    ...              ...
# 4995       0              0    2               0      0              189
# 4996       1              0    1               1      0              102
# 4997       0              0    3               0      0             1999
# 4998       0              0    3               1      2             3980
# 4999       1              0    1               0      0              321
#
#       Inflight wifi service  Departure/Arrival time convenient  \
# 0                         3                                  5
# 1                         2                                  4
# 2                         4                                  3
# 3                         5                                  1
# 4                         3                                  2
# ...                     ...                                ...
# 4995                      3                                  1
# 4996                      3                                  4
# 4997                      4                                  4
# 4998                      4                                  4
# 4999                      3                                  5
#
#       Ease of Online booking  Gate location  ...  Seat comfort  \
# 0                          5              5  ...             2
# 1                          1              1  ...             2
# 2                          4              4  ...             5
# 3                          2              1  ...             5
# 4                          3              4  ...             3
# ...                      ...            ...  ...           ...
# 4995                       3              4  ...             1
# 4996                       3              4  ...             3
# 4997                       4              1  ...             5
# 4998                       4              4  ...             5
# 4999                       3              1  ...             4
#
#       Inflight entertainment  On-board service  Leg room service  \
# 0                          3                 1                 1
# 1                          2                 5                 5
# 2                          4                 4                 4
# 3                          5                 3                 1
# 4                          3                 1                 3
# ...                      ...               ...               ...
# 4995                       1                 1                 3
# 4996                       3                 3                 2
# 4997                       5                 5                 4
# 4998                       4                 4                 4
# 4999                       4                 2                 3
#
#       Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                    3                4                 4            3
# 1                    1                1                 4            2
# 2                    4                4                 4            3
# 3                    5                5                 5            5
# 4                    3                2                 4            3
# ...                ...              ...               ...          ...
# 4995                 3                4                 4            1
# 4996                 2                3                 2            3
# 4997                 5                5                 4            5
# 4998                 4                5                 4            3
# 4999                 3                1                 2            4
#
#       Departure Delay in Minutes  satisfaction
# 0                             56             0
# 1                              0             1
# 2                              0             1
# 3                              0             1
# 4                              0             0
# ...                          ...           ...
# 4995                           0             0
# 4996                           0             0
# 4997                           4             1
# 4998                           8             1
# 4999                          13             0
#
# [5000 rows x 22 columns]

# %%
# gender
gend_alpha0 = 0.60
gend_beta1 = 0.40

aff_gend = np.array([[gend_alpha0,gend_beta1],
                     [gend_beta1,gend_alpha0]])

# customer type (loyal vs disoyal)

type_alpha0 = 0.8
type_beta1 = 0.5

aff_type = np.array([[type_alpha0, type_beta1],
                     [type_beta1, type_alpha0]])


# age
age_alpha0 = 0.90
age_beta1 = 0.80
age_beta2 = 0.60
age_beta3 = 0.40

aff_age = np.array([[age_alpha0,age_beta1,age_beta2,age_beta3],
                    [age_beta1,age_alpha0,age_beta1,age_beta2],
                    [age_beta2,age_beta1,age_alpha0,age_beta1],
                    [age_beta3,age_beta2,age_beta1,age_alpha0]])


# Type of travel
trav_type_alpha0 = 0.80
trav_type_beta1 = 0.40

aff_trav_type = np.array([[trav_type_alpha0, trav_type_beta1],
                          [trav_type_beta1, trav_type_alpha0]])

# Class

class_alpha0 = 0.85
class_beta1 = 0.60
class_beta2 = 0.40

aff_class = np.array([[class_alpha0, class_beta1, class_beta2],
                      [class_beta1, class_alpha0, class_beta1],
                      [class_beta2, class_beta1, class_alpha0]])


aff = {0:aff_gend, 1:aff_type, 2:aff_age, 3:aff_trav_type, 4:aff_class}

# %%
genvars = X[['Gender','Customer Type','Age','Type of Travel','Class']]

# %%
genvars
# Out:
#       Gender  Customer Type  Age  Type of Travel  Class
# 0          1              0    0               1      1
# 1          0              0    1               1      0
# 2          0              0    3               1      2
# 3          0              0    2               1      0
# 4          0              1    0               1      0
# ...      ...            ...  ...             ...    ...
# 4995       0              0    2               0      0
# 4996       1              0    1               1      0
# 4997       0              0    3               0      0
# 4998       0              0    3               1      2
# 4999       1              0    1               0      0
#
# [5000 rows x 5 columns]

# %%
x = genvars.to_numpy()
x = x.astype(int)
x = x.T

P_u_v = np.empty((len(x.T),len(x.T)))
prob_u_v = np.empty((len(x),1))
u = np.empty((len(x),1))
v = np.empty((len(x),1))

# create probability for connection between u and v
for i in range(len(x.T)):
    u = x[:,i]

    for k in range(len(x.T)):
        v = x[:,k]

        for j in range(len(x)):
            aff_current = aff[j]
            prob_u_v[j] = aff_current[u[j],v[j]]

        P_u_v[i,k] = np.prod(prob_u_v)

# %%
A = np.triu(P_u_v,0)

for i in range(len(P_u_v)):
    for j in range(len(P_u_v)):
        if A[i,j] > np.random.rand():
            A[i,j] = 1
        else:
            A[i,j] = 0

# %%
A = A + A.T - np.diag(np.diag(A))

# %%
G = nx.from_numpy_matrix(A)

# %%
nx.is_connected(G)
# Out:
# True

# %%
#nx.draw(G,node_size=20)

# %%
features = pd.Series(df.satisfaction) # invested or inv_pref

# %%
color_map = []
for i in features.items():
    if i[1] == 0:
        color_map.append('red')
    else:
        color_map.append('blue')

# %%
#pos = nx.spring_layout(G)

# %%
#nx.draw(G,pos,labels=features,node_size=20,node_color=color_map,with_labels=False)
#plt.show()

# %%
import dgl
import dgl.nn as dglnn
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.preprocessing import StandardScaler

G_dgl = dgl.from_networkx(G)
feat = df.drop(columns=['satisfaction'])
feat = pd.get_dummies(feat)
scale = StandardScaler()
feat = pd.DataFrame(scale.fit_transform(feat))

embedding = nn.Parameter(torch.tensor(feat.values,dtype=torch.float))

# embed = nn.Embedding(102, 5)  # 34 nodes with embedding dim equal to 5
G_dgl.ndata['feat'] =  embedding
G_dgl.ndata['train_mask'] = torch.zeros(len(G_dgl.nodes()), dtype=torch.bool).bernoulli(0.2)
G_dgl.ndata['label'] = torch.tensor(features)
# Out:
# Using backend: pytorch

# %%
G_dgl.ndata['val_mask'] = torch.empty(len(G_dgl.nodes()))
for i in range(len(G_dgl.ndata['train_mask'])):
    if G_dgl.ndata['train_mask'][i] == True:
        G_dgl.ndata['val_mask'][i] = False
    else:
        G_dgl.ndata['val_mask'][i] = True

G_dgl.ndata['val_mask'] = G_dgl.ndata['val_mask'].type(torch.bool)

# %%
# Contruct a two-layer GNN model

class GAT(nn.Module):
    def __init__(self, in_feats, hid_feats, out_feats):
        super().__init__()
        self.conv1 = dglnn.pytorch.conv.GATConv(
            in_feats=in_feats, out_feats=hid_feats, num_heads=1)
        self.conv2 = dglnn.pytorch.conv.GATConv(
            in_feats=hid_feats, out_feats=out_feats, num_heads=1)

    def forward(self, graph, inputs):
        # inputs are features of nodes
        h = self.conv1(graph, inputs)
        h = F.relu(h)
        h = self.conv2(graph, h)
        h = F.log_softmax(h,1)
        return h

# %%
def evaluate(model, graph, features, labels, mask):
    model.eval()
    with torch.no_grad():
        logits = model(graph, features)
        logits = logits.reshape(len(node_features),n_labels)
        logits = logits[mask]
        labels = labels[mask]
        _, indices = torch.max(logits, dim=1)
        correct = torch.sum(indices == labels)
        return correct.item() * 1.0 / len(labels)

# %%
node_features = G_dgl.ndata['feat']
node_labels = G_dgl.ndata['label']
train_mask = G_dgl.ndata['train_mask']
valid_mask = G_dgl.ndata['val_mask']
n_features = node_features.shape[1]
n_labels = int(node_labels.max().item() + 1)

# %%
model = GAT(in_feats=n_features, hid_feats=100, out_feats=n_labels)
opt = torch.optim.Adam(model.parameters())
plot_loss_train = []
plot_loss_val = []
valid_acc = []
train_acc = []
dur = []
for epoch in range(100):
    t0 = time.time()
    model.train()
    # forward propagation by using all nodes
    logits = model(G_dgl, node_features)
    logits = logits.reshape(len(node_features),n_labels)
    # compute loss
    loss_train = F.cross_entropy(logits[train_mask], node_labels[train_mask])
    loss_val = F.cross_entropy(logits[valid_mask], node_labels[valid_mask])
    plot_loss_train.append(loss_train.item())
    plot_loss_val.append(loss_val.item())
    # compute validation accuracy
    acc_val = evaluate(model, G_dgl, node_features, node_labels, valid_mask)
    acc_train = evaluate(model, G_dgl, node_features, node_labels, train_mask)
    valid_acc.append(acc_val)
    train_acc.append(acc_train)
    # backward propagation
    opt.zero_grad()
    loss_train.backward()
    opt.step()
    dur.append(time.time() - t0)
    if epoch % 10 == 0:
        print('Epoch: {}, train loss: {:.4f}, validation loss: {:.4f}, training accuracy: {:.4f}, validation accuracy: {:.4f}, Time: {:.4f}'.format(epoch,loss_train.item(),loss_val.item(),acc_train,acc_val,np.mean(dur)))
# Out:
# Epoch: 0, train loss: 0.6932, validation loss: 0.6931, training accuracy: 0.5679, validation accuracy: 0.5635, Time: 4.5502
# Epoch: 10, train loss: 0.6932, validation loss: 0.6931, training accuracy: 0.5679, validation accuracy: 0.5635, Time: 3.5981
# Epoch: 20, train loss: 0.6932, validation loss: 0.6931, training accuracy: 0.5679, validation accuracy: 0.5635, Time: 3.8696
# Epoch: 30, train loss: 0.6932, validation loss: 0.6931, training accuracy: 0.5679, validation accuracy: 0.5635, Time: 4.1567
# Epoch: 40, train loss: 0.6932, validation loss: 0.6931, training accuracy: 0.5679, validation accuracy: 0.5635, Time: 4.2788
# Epoch: 50, train loss: 0.6932, validation loss: 0.6931, training accuracy: 0.5679, validation accuracy: 0.5635, Time: 4.2075
# Epoch: 60, train loss: 0.6932, validation loss: 0.6931, training accuracy: 0.5679, validation accuracy: 0.5635, Time: 4.2505
# Epoch: 70, train loss: 0.6932, validation loss: 0.6931, training accuracy: 0.5679, validation accuracy: 0.5635, Time: 4.3069
# Epoch: 80, train loss: 0.6932, validation loss: 0.6931, training accuracy: 0.5679, validation accuracy: 0.5635, Time: 4.2058
# Epoch: 90, train loss: 0.6932, validation loss: 0.6931, training accuracy: 0.5679, validation accuracy: 0.5635, Time: 4.2952

# %%
plt.plot(plot_loss_train,label='Training Loss')
plt.plot(plot_loss_val,label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Cross Entropy Loss')
plt.legend()
plt.show()

# %%
plt.plot(train_acc,label='Training Accuracy')
plt.plot(valid_acc,label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
val_tens = torch.tensor(features)
_, indices_val = torch.max(logits[valid_mask], dim=1)
val_lab = val_tens[valid_mask]
train_lab = val_tens[train_mask]
_, indices_train = torch.max(logits[train_mask], dim=1)

print('Classification Accuracy validation set {}'.format(accuracy_score(val_lab,indices_val)))
print('-------------------------------------------------------------')
print('Classification Accuracy training set {}'.format(accuracy_score(train_lab,indices_train)))
print('-------------------------------------------------------------')
print('Confusion Matrix validation set:')
print(confusion_matrix(val_lab, indices_val))
print('-------------------------------------------------------------')
print('Confusion Matrix training set:')
print(confusion_matrix(train_lab,indices_train))
# Out:
# Classification Accuracy validation set 0.5635179153094463
# -------------------------------------------------------------
# Classification Accuracy training set 0.5678889990089198
# -------------------------------------------------------------
# Confusion Matrix validation set:
# [[2249    0]
#  [1742    0]]
# -------------------------------------------------------------
# Confusion Matrix training set:
# [[573   0]
#  [436   0]]

# %%
from sklearn.metrics import roc_auc_score, plot_roc_curve

roc_auc_score(val_lab,indices_val)
# Out:
# 0.5

# %%
#from node2vec import Node2Vec

#node2vec = Node2Vec(G, dimensions=30, walk_length=20, num_walks=100, workers=1)
#model = node2vec.fit(window=5, min_count=1, batch_words=2)
#model.wv.save_word2vec_format('embeddings')

# %%
#t = pd.read_csv('embeddings', delimiter = " ", index_col=0, header = None)
#t.sort_index(inplace=True)
#t = t.to_numpy()
#t.shape

# %%
#import statsmodels.api as sm

#log_reg = sm.Logit(features, t).fit()

# %%
from sklearn.model_selection import train_test_split
f = pd.get_dummies(features)
x_train, x_test, y_train, y_test = train_test_split(feat,f, test_size = 0.8, shuffle=True)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
x_train_tf = tf.convert_to_tensor(x_train)
x_test_tf = tf.convert_to_tensor(x_test)
y_train_tf = tf.convert_to_tensor(y_train)
y_test_tf = tf.convert_to_tensor(y_test)

model = Sequential()

model.add(Dense(15, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(2, activation='softmax'))
#opt = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(x_train_tf, y_train_tf,validation_data=(x_test_tf,y_test_tf), epochs=50, batch_size=5)
# Out:
# Epoch 1/50
# 200/200 [==============================] - 4s 15ms/step - loss: 0.8060 - accuracy: 0.4603 - val_loss: 0.6287 - val_accuracy: 0.7470
# Epoch 2/50
# 200/200 [==============================] - 2s 11ms/step - loss: 0.5989 - accuracy: 0.7489 - val_loss: 0.4605 - val_accuracy: 0.8385
# Epoch 3/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4250 - accuracy: 0.8599 - val_loss: 0.3540 - val_accuracy: 0.8612
# Epoch 4/50
# 200/200 [==============================] - 2s 9ms/step - loss: 0.3551 - accuracy: 0.8678 - val_loss: 0.3230 - val_accuracy: 0.8733
# Epoch 5/50
# 200/200 [==============================] - 1s 5ms/step - loss: 0.3007 - accuracy: 0.8908 - val_loss: 0.3069 - val_accuracy: 0.8802
# Epoch 6/50
# 200/200 [==============================] - 1s 6ms/step - loss: 0.2906 - accuracy: 0.9022 - val_loss: 0.2983 - val_accuracy: 0.8882
# Epoch 7/50
# 200/200 [==============================] - 1s 5ms/step - loss: 0.2421 - accuracy: 0.9170 - val_loss: 0.2911 - val_accuracy: 0.8932
# Epoch 8/50
# 200/200 [==============================] - 1s 5ms/step - loss: 0.2348 - accuracy: 0.9193 - val_loss: 0.2852 - val_accuracy: 0.8932
# Epoch 9/50
# 200/200 [==============================] - 1s 5ms/step - loss: 0.2231 - accuracy: 0.9297 - val_loss: 0.2812 - val_accuracy: 0.8963
# Epoch 10/50
# 200/200 [==============================] - 1s 6ms/step - loss: 0.2120 - accuracy: 0.9345 - val_loss: 0.2784 - val_accuracy: 0.8978
# Epoch 11/50
# 200/200 [==============================] - 1s 5ms/step - loss: 0.2272 - accuracy: 0.9205 - val_loss: 0.2722 - val_accuracy: 0.8967
# Epoch 12/50
# 200/200 [==============================] - 1s 5ms/step - loss: 0.2150 - accuracy: 0.9236 - val_loss: 0.2691 - val_accuracy: 0.8988
# Epoch 13/50
# 200/200 [==============================] - 1s 6ms/step - loss: 0.1936 - accuracy: 0.9321 - val_loss: 0.2692 - val_accuracy: 0.8972
# Epoch 14/50
# 200/200 [==============================] - 1s 6ms/step - loss: 0.1879 - accuracy: 0.9336 - val_loss: 0.2642 - val_accuracy: 0.9007
# Epoch 15/50
# 200/200 [==============================] - 1s 5ms/step - loss: 0.1974 - accuracy: 0.9305 - val_loss: 0.2626 - val_accuracy: 0.9013
# Epoch 16/50
# 200/200 [==============================] - 2s 9ms/step - loss: 0.1526 - accuracy: 0.9435 - val_loss: 0.2621 - val_accuracy: 0.9010
# Epoch 17/50
# 200/200 [==============================] - 2s 9ms/step - loss: 0.1788 - accuracy: 0.9308 - val_loss: 0.2619 - val_accuracy: 0.8997
# Epoch 18/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.1639 - accuracy: 0.9358 - val_loss: 0.2607 - val_accuracy: 0.9050
# Epoch 19/50
# 200/200 [==============================] - 2s 8ms/step - loss: 0.1501 - accuracy: 0.9470 - val_loss: 0.2608 - val_accuracy: 0.9010
# Epoch 20/50
# 200/200 [==============================] - 1s 5ms/step - loss: 0.1311 - accuracy: 0.9565 - val_loss: 0.2665 - val_accuracy: 0.8995
# Epoch 21/50
# 200/200 [==============================] - 1s 6ms/step - loss: 0.1533 - accuracy: 0.9477 - val_loss: 0.2600 - val_accuracy: 0.9013
# Epoch 22/50
# 200/200 [==============================] - 1s 6ms/step - loss: 0.1584 - accuracy: 0.9468 - val_loss: 0.2608 - val_accuracy: 0.9028
# Epoch 23/50
# 200/200 [==============================] - 1s 6ms/step - loss: 0.1115 - accuracy: 0.9634 - val_loss: 0.2618 - val_accuracy: 0.9038
# Epoch 24/50
# 200/200 [==============================] - 1s 6ms/step - loss: 0.1174 - accuracy: 0.9675 - val_loss: 0.2617 - val_accuracy: 0.9025
# Epoch 25/50
# 200/200 [==============================] - 1s 5ms/step - loss: 0.1114 - accuracy: 0.9647 - val_loss: 0.2642 - val_accuracy: 0.9007
# Epoch 26/50
# 200/200 [==============================] - 1s 5ms/step - loss: 0.1202 - accuracy: 0.9587 - val_loss: 0.2688 - val_accuracy: 0.8978
# Epoch 27/50
# 200/200 [==============================] - 1s 6ms/step - loss: 0.0901 - accuracy: 0.9809 - val_loss: 0.2693 - val_accuracy: 0.9022
# Epoch 28/50
# 200/200 [==============================] - 1s 6ms/step - loss: 0.1055 - accuracy: 0.9680 - val_loss: 0.2722 - val_accuracy: 0.8978
# Epoch 29/50
# 200/200 [==============================] - 1s 5ms/step - loss: 0.1067 - accuracy: 0.9740 - val_loss: 0.2714 - val_accuracy: 0.9035
# Epoch 30/50
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0979 - accuracy: 0.9675 - val_loss: 0.2732 - val_accuracy: 0.9003
# Epoch 31/50
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0921 - accuracy: 0.9693 - val_loss: 0.2792 - val_accuracy: 0.8960
# Epoch 32/50
# 200/200 [==============================] - 1s 7ms/step - loss: 0.1028 - accuracy: 0.9698 - val_loss: 0.2786 - val_accuracy: 0.8982
# Epoch 33/50
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0864 - accuracy: 0.9750 - val_loss: 0.2826 - val_accuracy: 0.8967
# Epoch 34/50
# 200/200 [==============================] - 1s 6ms/step - loss: 0.0879 - accuracy: 0.9792 - val_loss: 0.2835 - val_accuracy: 0.8990
# Epoch 35/50
# 200/200 [==============================] - 1s 6ms/step - loss: 0.0844 - accuracy: 0.9771 - val_loss: 0.2884 - val_accuracy: 0.8950
# Epoch 36/50
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0776 - accuracy: 0.9846 - val_loss: 0.2924 - val_accuracy: 0.8953
# Epoch 37/50
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0943 - accuracy: 0.9703 - val_loss: 0.2936 - val_accuracy: 0.8955
# Epoch 38/50
# 200/200 [==============================] - 1s 6ms/step - loss: 0.0809 - accuracy: 0.9794 - val_loss: 0.2950 - val_accuracy: 0.8957
# Epoch 39/50
# 200/200 [==============================] - 1s 6ms/step - loss: 0.0791 - accuracy: 0.9791 - val_loss: 0.2979 - val_accuracy: 0.8935
# Epoch 40/50
# 200/200 [==============================] - 1s 5ms/step - loss: 0.0878 - accuracy: 0.9762 - val_loss: 0.3002 - val_accuracy: 0.8928
# Epoch 41/50
# 200/200 [==============================] - 1s 6ms/step - loss: 0.0693 - accuracy: 0.9852 - val_loss: 0.3050 - val_accuracy: 0.8940
# Epoch 42/50
# 200/200 [==============================] - 1s 6ms/step - loss: 0.0634 - accuracy: 0.9837 - val_loss: 0.3063 - val_accuracy: 0.8930
# Epoch 43/50
# 200/200 [==============================] - 3s 16ms/step - loss: 0.0532 - accuracy: 0.9831 - val_loss: 0.3110 - val_accuracy: 0.8910
# Epoch 44/50
# 200/200 [==============================] - 3s 14ms/step - loss: 0.0473 - accuracy: 0.9895 - val_loss: 0.3146 - val_accuracy: 0.8920
# Epoch 45/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.0605 - accuracy: 0.9833 - val_loss: 0.3197 - val_accuracy: 0.8920
# Epoch 46/50
# 200/200 [==============================] - 3s 16ms/step - loss: 0.0758 - accuracy: 0.9836 - val_loss: 0.3264 - val_accuracy: 0.8947
# Epoch 47/50
# 200/200 [==============================] - 3s 15ms/step - loss: 0.0596 - accuracy: 0.9820 - val_loss: 0.3262 - val_accuracy: 0.8913
# Epoch 48/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.0490 - accuracy: 0.9886 - val_loss: 0.3328 - val_accuracy: 0.8925
# Epoch 49/50
# 200/200 [==============================] - 1s 7ms/step - loss: 0.0500 - accuracy: 0.9884 - val_loss: 0.3361 - val_accuracy: 0.8920
# Epoch 50/50
# 200/200 [==============================] - 1s 7ms/step - loss: 0.0481 - accuracy: 0.9898 - val_loss: 0.3389 - val_accuracy: 0.8930

# %%
plt.plot(history.history['loss'],label = 'Training Loss', color = 'blue')
plt.plot(history.history['val_loss'],label = 'Validation Loss', color = 'red')
plt.xlabel('Number of Epochs')
plt.ylabel('Cross-Entropy Loss')
plt.title('Loss per Epoch')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'],label = 'Training accuracy', color = 'blue')
plt.plot(history.history['val_accuracy'],label = 'Validation accuracy', color = 'red')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy per Epoch')
plt.legend()
plt.show()

# %%
df_test = pd.read_csv('test.csv',sep=',')
df_test = df_test.sample(n=5000)
df_test.drop(columns=['Unnamed: 0','id'],inplace=True)
df_test.Gender = df_test.Gender.apply(lambda x: 0 if x == 'Male' else 1)
df_test['Customer Type'] = df_test['Customer Type'].apply(lambda x: 0 if x == 'Loyal Customer' else 1)
df_test['Type of Travel'] = df_test['Type of Travel'].apply(lambda x: 0 if x == 'Personal Travel' else 1)
df_test['Class'] = df_test['Class'].apply(lambda x: 0 if x == 'Eco' else(1 if x == 'Eco Plus' else 2))
df_test['satisfaction'] = df_test['satisfaction'].apply(lambda x: 0 if x == 'neutral or dissatisfied' else 1)
df_test.reset_index(drop=True,inplace=True)
df_test.drop(columns=['Arrival Delay in Minutes'],inplace = True)

# %%
X = df_test
X.Age = X.Age.apply(lambda x: 0 if x < 26 else(1 if x < 39 else(2 if x < 50 else 3)))
genvars = X[['Gender','Customer Type','Age','Type of Travel','Class']]

# %%
genvars
# Out:
#       Gender  Customer Type  Age  Type of Travel  Class
# 0          1              0    2               1      0
# 1          1              0    1               0      0
# 2          0              0    0               0      0
# 3          1              0    2               1      2
# 4          1              0    0               0      0
# ...      ...            ...  ...             ...    ...
# 4995       0              0    1               1      2
# 4996       1              0    3               0      0
# 4997       0              0    0               0      0
# 4998       0              0    2               1      2
# 4999       1              0    2               1      2
#
# [5000 rows x 5 columns]

# %%
x = genvars.to_numpy()
x = x.astype(int)
x = x.T

P_u_v = np.empty((len(x.T),len(x.T)))
prob_u_v = np.empty((len(x),1))
u = np.empty((len(x),1))
v = np.empty((len(x),1))

# create probability for connection between u and v
for i in range(len(x.T)):
    u = x[:,i]

    for k in range(len(x.T)):
        v = x[:,k]

        for j in range(len(x)):
            aff_current = aff[j]
            prob_u_v[j] = aff_current[u[j],v[j]]

        P_u_v[i,k] = np.prod(prob_u_v)

# %%
A = np.triu(P_u_v,0)

for i in range(len(P_u_v)):
    for j in range(len(P_u_v)):
        if A[i,j] > np.random.rand():
            A[i,j] = 1
        else:
            A[i,j] = 0

# %%
A = A + A.T - np.diag(np.diag(A))

# %%
G_test = nx.from_numpy_matrix(A)

# %%
features = pd.Series(df_test.satisfaction) # invested or inv_pref

# %%
G_dgl_test = dgl.from_networkx(G_test)
feat = df_test.drop(columns=['satisfaction'])
feat = pd.get_dummies(feat)
scale = StandardScaler()
feat = pd.DataFrame(scale.fit_transform(feat))

embedding = nn.Parameter(torch.tensor(feat.values,dtype=torch.float))

# embed = nn.Embedding(102, 5)  # 34 nodes with embedding dim equal to 5
G_dgl_test.ndata['feat'] =  embedding
#G_dgl.ndata['train_mask'] = torch.zeros(len(G_dgl.nodes()), dtype=torch.bool).bernoulli(0.2)
G_dgl_test.ndata['label'] = torch.tensor(features)

# %%
node_features = G_dgl_test.ndata['feat']
node_labels = G_dgl_test.ndata['label']
#train_mask = G_dgl.ndata['train_mask']
#valid_mask = G_dgl.ndata['val_mask']
n_features = node_features.shape[1]
n_labels = int(node_labels.max().item() + 1)

# %%
def evaluate(model, graph, features, labels):
    model.eval()
    with torch.no_grad():
        logits = model(graph, features)
        logits = logits.reshape(len(node_features),n_labels)
        _, indices = torch.max(logits, dim=1)
        correct = torch.sum(indices == labels)
        return correct.item() * 1.0 / len(labels)

# %%
model = GAT(in_feats=n_features, hid_feats=50, out_feats=n_labels)
model.eval()
logits = model(G_dgl_test, node_features)
logits = logits.reshape(len(node_features),n_labels)
loss = F.cross_entropy(logits, node_labels)
acc = evaluate(model, G_dgl_test, node_features, node_labels)

# %%
acc
# Out:
# 0.5612

# %%
val_tens = torch.tensor(features)
_, indices_val = torch.max(logits, dim=1)
val_lab = val_tens

print('Classification Accuracy validation set {}'.format(accuracy_score(val_lab,indices_val)))
print('-------------------------------------------------------------')
print('Confusion Matrix validation set:')
print(confusion_matrix(val_lab, indices_val))
# Out:
# Classification Accuracy validation set 0.5612
# -------------------------------------------------------------
# Confusion Matrix validation set:
# [[2806    0]
#  [2194    0]]
